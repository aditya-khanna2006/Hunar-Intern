# %% [markdown]
# # **Data Cleaning Internship Task**
# #  **Hunar Intern – Task 1**

# %% [markdown]
# ## **Objective**
#
# The objective of this project is to clean the dataset by handling missing values, removing duplicate rows and duplicate columns, and preparing the dataset for further analysis.

# %% [markdown]
# ## **Step 1: Import Required Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Step 2: Load the Dataset**

# %%
df = pd.read_csv("food_coded.csv")

# %% [markdown]
# ## **Step 3: Display First Five Rows**

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %% [markdown]
# ## **Step 4: Explore the Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
df.shape
# Out:
# (125, 61)

# %% [markdown]
# ## **Step 5: Check Missing Values**

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %% [markdown]
# ## **Step 6: Handle Missing Values**

# %%
# Numeric columns
numeric_cols = df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

# Categorical columns
categorical_cols = df.select_dtypes(include="object").columns
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ## **Step 7: Remove Duplicate Rows and Duplicate Columns**

# %%
df.drop_duplicates(inplace=True)

df = df.loc[:, ~df.columns.duplicated()]

# %% [markdown]
# ## **Step 8: Verify the Cleaned Dataset**

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:", df.duplicated().sum())

print("\nDuplicate Columns:", df.columns.duplicated().sum())

print("\nShape:", df.shape)
# Out:
# Missing Values:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64
#
# Duplicate Rows: 0
#
# Duplicate Columns: 0
#
# Shape: (125, 61)

# %% [markdown]
# ## **Step 9: Save the Cleaned Dataset**

# %%
df.to_csv("food_coded_cleaned.csv", index=False)

# %% [markdown]
# # **Conclusion**
#
# The dataset was successfully cleaned by handling missing values using appropriate imputation techniques. Duplicate rows and duplicate columns were removed successfully. The cleaned dataset is now ready for further analysis and machine learning applications.
